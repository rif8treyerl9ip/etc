# %% [markdown]
# https://nanjamonja.net/archives/303

# %%
import pandas as pd
from pandas import Series, DataFrame
import pandas_datareader.data as web
import numpy as np
import datetime
 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2021, 4, 19)
 
GOOG = web.DataReader('GOOG', 'yahoo', start, end)
 
pd_data.tail()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2021-04-12  2275.320068  2238.465088  2266.250000  2254.790039  1565900
# 2021-04-13  2277.209961  2256.090088  2261.469971  2267.270020  1165500
# 2021-04-14  2277.989990  2249.189941  2275.159912  2254.840088  1011000
# 2021-04-15  2306.596924  2266.000000  2276.979980  2296.659912  1373600
# 2021-04-16  2306.439941  2284.449951  2303.000000  2297.760010  1129800
#
#               Adj Close
# Date
# 2021-04-12  2254.790039
# 2021-04-13  2267.270020
# 2021-04-14  2254.840088
# 2021-04-15  2296.659912
# 2021-04-16  2297.760010

# %%
GOOG['High'].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from datetime import datetime
 
# stock_list = ['AAPL', 'GOOG', 'SNE']
end_ = datetime.now()
start_ = datetime(end.year - 1, end.month, end.day)    
 
df_2 = web.DataReader(['AAPL', 'GOOG', 'SONY'], 'yahoo', start_, end_)
print(type(df_2.index))
df_2.head()
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# Attributes  Adj Close                              Close               \
# Symbols          AAPL         GOOG       SONY       AAPL         GOOG
# Date
# 2020-04-20  68.699974  1266.609985  63.549999  69.232498  1266.609985
# 2020-04-21  66.576424  1216.339966  62.049999  67.092499  1216.339966
# 2020-04-22  68.494064  1263.209961  62.680000  69.025002  1263.209961
# 2020-04-23  68.228622  1276.310059  62.060001  68.757500  1276.310059
# 2020-04-24  70.198349  1279.310059  62.959999  70.742500  1279.310059
#
# Attributes                  High                                Low  \
# Symbols          SONY       AAPL         GOOG       SONY       AAPL
# Date
# 2020-04-20  63.549999  70.419998  1281.599976  64.430000  69.212502
# 2020-04-21  62.049999  69.312500  1254.270020  62.650002  66.357498
# 2020-04-22  62.680000  69.474998  1285.613037  62.980000  68.050003
# ...

# %%
df_2['Adj Close'].loc[df_2.index[0], 'AAPL']
# Out:
# 1266.6099853515625

# %%
df_2['Adj Close','AAPL'] /= df_2['Adj Close'].loc[df_2.index[0],'AAPL']
df_2['Adj Close','GOOG'] /= df_2['Adj Close'].loc[df_2.index[0],'GOOG']
df_2['Adj Close','SONY'] /= df_2['Adj Close'].loc[df_2.index[0],'SONY']

df_2['Adj Close'].plot(title='apple,google,sony',figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'apple,google,sony'}, xlabel='Date'>
