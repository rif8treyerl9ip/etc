# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # matplotlib.pyplot をインポートし、以下 plt と呼ぶ。

# https://www.kaggle.com/abcsds/pokemon から取得した Pokemon.csv を読み込む。
df = pd.read_csv("Pokemon.csv") # df とは、 pandas の DataFrame 形式のデータを入れる変数として命名

# %%
import sys
sys.path.append('../analytics_lib')
from analytics_linear import all_linear_regression

# 可視化
from viz_first import visualize
subset=['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
violinplot_columns=df.columns[4:11]
visualize(df,subset,violinplot_columns,print_unique=False,sample_size=False)
# Out:
# 以下の情報を表示します
#   - NUM OF NULL(normal, any, all) & DTYPES
#   - FIRST 50 RECORD
#   - DESCRIBE
#   - SCATTER PLOT MATRIX
#   - CORRELATION MATRIX
#   - VIOLINPLOT
#
#
# NUM OF NULL & DTYPES:
#                      #    Name  Type 1  Type 2  Total     HP Attack Defense  \
# num_of_null          0       0       0     386      0      0      0       0
# dtypes           int64  object  object  object  int64  int64  int64   int64
# all_null_record      0     NaN     NaN     NaN    NaN    NaN    NaN     NaN
# any_null_record    386     NaN     NaN     NaN    NaN    NaN    NaN     NaN
#
#                 Sp. Atk Sp. Def  Speed Generation Legendary
# num_of_null           0       0      0          0         0
# dtypes            int64   int64  int64      int64      bool
# all_null_record     NaN     NaN    NaN        NaN       NaN
# any_null_record     NaN     NaN    NaN        NaN       NaN
# FIRST 50 RECORD:
# <style type="text/css">
# ...

# %%
scoredf,coef_list = all_linear_regression(df)
scoredf
# Out:
#                                         #               Total  \
# mean_squared_error_tr          1261.63612                 0.0
# mean_squared_error_te         1277.016607                 0.0
# r2_tr                            0.970685                 1.0
# r2_te                            0.971033                 1.0
# model                  LinearRegression()  LinearRegression()
#
#                                        HP              Attack  \
# mean_squared_error_tr                 0.0                 0.0
# mean_squared_error_te                 0.0                 0.0
# r2_tr                                 1.0                 1.0
# r2_te                                 1.0                 1.0
# model                  LinearRegression()  LinearRegression()
#
#                                   Defense             Sp. Atk  \
# mean_squared_error_tr                 0.0                 0.0
# mean_squared_error_te                 0.0                 0.0
# ...

# %%
# Out:
# 正解率(train):  0.9607142857142857
# 正解率(test):  0.9625
#              real 0  real 1
# predicted 0       0       0
# predicted 1       0       0
